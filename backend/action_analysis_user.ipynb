# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Function to plot top 5 user actions for a specific user_id
def plot_top_user_actions(user_id):
    # Filter data for the given user_id and the past one month
    one_month_ago = datetime.now() - timedelta(days=30)
    filtered_data = df[(df['customer_id'] == user_id) & (df['timestamp'] >= one_month_ago)]

    # Get the top 5 actions and their counts
    top_actions = filtered_data['action'].value_counts().nlargest(5)

    # Plotting
    top_actions.plot(kind='bar', color='skyblue')
    plt.title(f'Top 5 User Actions for Customer {user_id} (Past One Month)')
    plt.xlabel('Action')
    plt.ylabel('Action Count')
    plt.show()

# Example: Plotting for customer_id 1
plot_top_user_actions(1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

df = pd.DataFrame(data)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Function to plot top 5 user actions for a specific user_id
def plot_top_user_actions(user_id):
    # Filter data for the given user_id and the past one month
    one_month_ago = datetime.now() - timedelta(days=30)
    filtered_data = df[(df['customer_id'] == user_id) & (df['timestamp'] >= one_month_ago)]

    # Check if there is data for the specified user and time period
    if not filtered_data.empty:
        # Get the top 5 actions and their counts
        top_actions = filtered_data['action'].value_counts().nlargest(5)

        # Plotting
        top_actions.plot(kind='bar', color='skyblue')
        plt.title(f'Top 5 User Actions for Customer {user_id} (Past One Month)')
        plt.xlabel('Action')
        plt.ylabel('Action Count')
        plt.show()
    else:
        print(f"No data available for Customer {user_id} in the past one month.")

# Example: Plotting for customer_id 1
plot_top_user_actions(1)
